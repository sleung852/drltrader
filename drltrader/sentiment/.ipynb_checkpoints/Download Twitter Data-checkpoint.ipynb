# %% [markdown]
# # Scraping Market News from Twitter
# So all major finance news sources have twitter accounts. In fact even one news institution may have multiple accounts. For example, Financial Times has @FT, @FinancialTimes, @FTMarkets, @fteconomics etc. <br><br>  So I decided to scrape the following market related accounts:
# 1. @FTMarkets - Financial Times Markets (21.2K followers)
# 2. @markets - Bloomberg Markets (987.8K followers)
# 3. @WSJbusiness - Wall Street Journal Business (1.6M followers)
# 4. @ReutersBiz - Reuters Business (2.2M followers)
# 5. @BBCBusiness - BBC Business (1.9M followers)
# 6. @CNBC - CNBC (4.1M followers)
# 7. @TheEconomist - The Economist (main account) (25.7M followers) [optional]

# %%
import pandas as pd
import itertools
from datetime import timedelta, date

from snscrape.modules import twitter
import os
import time
from tqdm.notebook import tqdm, trange

# %% [markdown]
# ## How snscrape works?

# %%
# # simple test 
# keyword = 'from:@FT since:2021-04-01 until:2021-04-02'
# scraped_tweets = twitter.TwitterSearchScraper(keyword).get_items()
# sliced_scraped_tweets = itertools.islice(scraped_tweets, 10000)

# %% [markdown]
# ## Build my own Scraper

# %%
tar_acs = {
    'ftmarkets': '@FTMarkets',
    'bloombergmarkets': '@markets',
    'wsjbusiness': '@WSJbusiness',
    'reutersbusiness': '@ReutersBiz',
    #'theeconomist': '@TheEconomist',
    'bbcbusiness': '@BBCBusiness',
    'cnbc': '@CNBC'
}

# %%
# ensure data director folders exist
data_dir = 'data/twitter/'
for name in tar_acs.keys():
    tar_dir = os.path.join(data_dir, name)
    if not os.path.isdir(tar_dir):
        os.mkdir(tar_dir)

# %%
# function to return a range of dates
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# function to scrape twitter posts in general from a specific account
def scrape_twitter(target, start_date, end_date, limit=10000):
    query_str = f'from:{tar_acs[target]} since:{str(start_date)} until:{str(end_date)}'
    twt_generator = twitter.TwitterSearchScraper(keyword).get_items()
    sliced_scraped_tweets = itertools.islice(twt_generator, limit)
    return pd.DataFrame(sliced_scraped_tweets)

# function to scrape twitter posts in batch from a specific account
def scrape_twitter_batch_and_save(target, start_date, end_date, wait_time=10, daily_limit=10000):
    dates = [single_date for single_date in daterange(start_date, end_date+timedelta(1))]
    for i in trange(len(dates)):
        df = scrape_twitter(target, dates[i], dates[i+1], limit=daily_limit)
        file_name = f'{target}_{str(start_date)}_{str(end_date)}.csv'
        df.to_csv(os.path.join(data_dir, target, file_name), index=None)
        time.sleep(wait_time)

# %%
# quick test 
df = scrape_twitter('ftmarkets', date(2021, 1, 1), date(2021, 1, 2))
df.head()
# Out:
#                                                   url  \
# 0   https://twitter.com/FT/status/1378106329764663299
# 1   https://twitter.com/FT/status/1378091582075899912
# 2   https://twitter.com/FT/status/1378075869562953742
# 3   https://twitter.com/FT/status/1378071687728615432
# 4   https://twitter.com/FT/status/1378048453234864128
# 5   https://twitter.com/FT/status/1378043951794556932
# 6   https://twitter.com/FT/status/1378038821892292613
# 7   https://twitter.com/FT/status/1378035492462211075
# 8   https://twitter.com/FT/status/1378030389260865540
# 1   <a href="http://www.socialflow.com" rel="nofol...
# 2   <a href="http://www.socialflow.com" rel="nofol...
# 3   <a href="http://www.socialflow.com" rel="nofol...
# 4   <a href="http://www.socialflow.com" rel="nofol...
# 5   <a href="http://www.socialflow.com" rel="nofol...
# 6   <a href="http://www.socialflow.com" rel="nofol...
# 7   <a href="http://www.socialflow.com" rel="nofol...
# 8   <a href="http://www.socialflow.com" rel="nofol...
# 9   <a href="http://www.socialflow.com" rel="nofol...
# 10  <a href="http://www.socialflow.com" rel="nofol...
# 11  <a href="http://www.socialflow.com" rel="nofol...
# 12  <a href="http://www.socialflow.com" rel="nofol...
# 13  <a href="http://www.socialflow.com" rel="nofol...
# 14  <a href="http://www.socialflow.com" rel="nofol...
# 15  <a href="http://www.socialflow.com" rel="nofol...
# 16  <a href="http://www.socialflow.com" rel="nofol...
# 17  <a href="http://www.socialflow.com" rel="nofol...
# 18  <a href="http://www.socialflow.com" rel="nofol...
# 19  <a href="http://www.socialflow.com" rel="nofol...
# 20  <a href="http://www.socialflow.com" rel="nofol...
# 21  <a href="http://www.socialflow.com" rel="nofol...
# 22  <a href="http://www.socialflow.com" rel="nofol...
# 23  <a href="http://www.socialflow.com" rel="nofol...
# 24  <a href="http://www.socialflow.com" rel="nofol...
# 25  <a href="http://www.socialflow.com" rel="nofol...
# 26  <a href="http://www.socialflow.com" rel="nofol...
# 27  <a href="http://www.socialflow.com" rel="nofol...
# 28  <a href="http://www.socialflow.com" rel="nofol...
# 29  <a href="http://www.socialflow.com" rel="nofol...
# 30  <a href="http://www.socialflow.com" rel="nofol...
# 31  <a href="http://www.socialflow.com" rel="nofol...
#
#                     sourceUrl sourceLabel media retweetedTweet quotedTweet  \
# 0   http://www.socialflow.com  SocialFlow  None           None        None
# 1   http://www.socialflow.com  SocialFlow  None           None        None
# 2   http://www.socialflow.com  SocialFlow  None           None        None
# 3   http://www.socialflow.com  SocialFlow  None           None        None
# 4   http://www.socialflow.com  SocialFlow  None           None        None
# 5   http://www.socialflow.com  SocialFlow  None           None        None
# 6   http://www.socialflow.com  SocialFlow  None           None        None
# 7   http://www.socialflow.com  SocialFlow  None           None        None
# 8   http://www.socialflow.com  SocialFlow  None           None        None
# 9   http://www.socialflow.com  SocialFlow  None           None        None
# 10  http://www.socialflow.com  SocialFlow  None           None        None
# 11  http://www.socialflow.com  SocialFlow  None           None        None
# 12  http://www.socialflow.com  SocialFlow  None           None        None
# 13  http://www.socialflow.com  SocialFlow  None           None        None
# 14  http://www.socialflow.com  SocialFlow  None           None        None
# 15  http://www.socialflow.com  SocialFlow  None           None        None
# 16  http://www.socialflow.com  SocialFlow  None           None        None
# 17  http://www.socialflow.com  SocialFlow  None           None        None
# 18  http://www.socialflow.com  SocialFlow  None           None        None
# 19  http://www.socialflow.com  SocialFlow  None           None        None
# 20  http://www.socialflow.com  SocialFlow  None           None        None
# 21  http://www.socialflow.com  SocialFlow  None           None        None
# 22  http://www.socialflow.com  SocialFlow  None           None        None
# 23  http://www.socialflow.com  SocialFlow  None           None        None
# 24  http://www.socialflow.com  SocialFlow  None           None        None
# 25  http://www.socialflow.com  SocialFlow  None           None        None
# 26  http://www.socialflow.com  SocialFlow  None           None        None
# 27  http://www.socialflow.com  SocialFlow  None           None        None
# 28  http://www.socialflow.com  SocialFlow  None           None        None
# 29  http://www.socialflow.com  SocialFlow  None           None        None
# 30  http://www.socialflow.com  SocialFlow  None           None        None
# 31  http://www.socialflow.com  SocialFlow  None           None        None
#
#    mentionedUsers
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
#
# [32 rows x 21 columns]

# %%
scrape_twitter_batch_and_save('ftmarkets', date(2021, 1, 1), date(2021, 4, 30))
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x7f818709d310>
# Traceback (most recent call last):
#   File "/home/see/anaconda3/envs/env_scraper/lib/python3.8/site-packages/tqdm/std.py", line 1145, in __del__
#     self.close()
#   File "/home/see/anaconda3/envs/env_scraper/lib/python3.8/site-packages/tqdm/notebook.py", line 283, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-65-8fb0e318ffc4> in <module>
# ----> 1 scrape_twitter_batch_and_save('ftmarkets', date(2021, 1, 1), date(2021, 4, 30))
#
# <ipython-input-64-5f3ab8407459> in scrape_twitter_batch_and_save(target, start_date, end_date, wait_time, daily_limit)
#      14 def scrape_twitter_batch_and_save(target, start_date, end_date, wait_time=10, daily_limit=10000):
#      15     dates = [single_date for single_date in daterange(start_date, end_date+timedelta(1))]
# ---> 16     for i in trange(len(dates)):
#      17         df = scrape_twitter(target, dates[i], dates[i+1], limit=daily_limit)
#      18         file_name = f'{target}_{str(start_date)}_{str(end_date)}.csv'
#
# ~/anaconda3/envs/env_scraper/lib/python3.8/site-packages/tqdm/notebook.py in tnrange(*args, **kwargs)
#     317     On Python3+, `range` is used instead of `xrange`.
#     318     """
# --> 319     return tqdm_notebook(_range(*args), **kwargs)
#     320
#     321
#
# ~/anaconda3/envs/env_scraper/lib/python3.8/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     237         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     238         total = self.total * unit_scale if self.total else self.total
# --> 239         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     240         self.container.pbar = self
#     241         self.displayed = False
#
# ~/anaconda3/envs/env_scraper/lib/python3.8/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     110         # Prepare IPython progress bar
#     111         if IProgress is None:  # #187 #451 #558 #872
# --> 112             raise ImportError(
#     113                 "IProgress not found. Please update jupyter and ipywidgets."
#     114                 " See https://ipywidgets.readthedocs.io/en/stable"
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
